# %%
import matplotlib.pyplot as plt

#Take input from user

x = list(map(float, input("Enter X values separated by spaces: ").split()))

.split()))

y = list(map(float, input("Enter Y values separated by spaces: ")

#Check if Lengths match

if len(x) != len(y):

print("Error: X and Y must have the same number of values.")

else:

# Draw Line graph

plt.plot(x, y, marker='o')

# Labels and title

plt.xlabel("X-axis")

plt.ylabel("Y-axis")

plt.title("Line Graph (User Input)")

#Show the graph

plt.show()
