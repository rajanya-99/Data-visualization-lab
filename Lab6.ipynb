# %%
import networkx as nx

import matplotlib.pyplot as plt

n = int(input("Enter number of vertices (must be greater than 3): "))

#Get number of vertices from user

if n < 3:

    print("Number of vertices must be greater than 3.")

else:

#Create a complete graph
    
    Gnx.complete_graph(n)
    
    #Drow the graph
    
    plt.figure(figsize-(6, 6))
    
    pos = nx.circular_layout(6) # nice circular layout
    
    nx.draw(
        
        G,
        
        pos,
        
        with_labels=True,
        
        node_color='lightblue',
        
        node_size=800,
        
        edge_color='gray',
        
        font_size=10
    )

plt.title(f"Complete Graph with (n) Vertices")

plt.show()
# Out:
# Enter number of vertices (must be greater than 3):  7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      11     print("Number of vertices must be greater than 3.")
#      13 else:
#      14
#      15 #Create a complete graph
# ---> 17     Gnx.complete_graph(n)
#      19     #Drow the graph
#      21     plt.figure(figsize-(6, 6))
#
# NameError: name 'Gnx' is not defined
